# %%
import ipyplot

import rawpy 
import cv2
import numpy as np


from skimage.exposure import match_histograms, equalize_hist
from skimage.transform import rescale

import os
import os.path as op

data_dir = op.join("..", "data")
img_name = "DSC01088"
raw_fp = op.join(data_dir, img_name+".ARW")
jpg_fp = op.join(data_dir, img_name+".JPG")

assert op.exists(raw_fp)
assert op.exists(jpg_fp)

# %% [markdown]
# ## funcs.

# %%
def read_avg_green_raw(filepath):
    _img = rawpy.imread(filepath)
    img = _img.raw_image.copy()
    img = np.expand_dims(img,axis=2)
    black_level = _img.black_level_per_channel[0] # assume all black level is the same
    img = (np.maximum(img - black_level, 0) + black_level)/2**16
    H = img.shape[0]
    W = img.shape[1]
    packed_img = np.concatenate((img[0:H:2, 0:W:2, :],        # R
                              img[0:H:2, 1:W:2, :],           # GR
                              img[1:H:2, 0:W:2, :],           # GB
                              img[1:H:2, 1:W:2, :]), axis=2)  # B
    greens = (packed_img[:, :, 1]+packed_img[:, :, 2]/2)/2 # RGGB
    return greens

# %% [markdown]
# ## Read and process

# %%
jpg = cv2.imread(jpg_fp)
jpg = cv2.cvtColor(jpg, cv2.COLOR_BGR2GRAY)
raw = read_avg_green_raw(raw_fp)

print(jpg.shape, raw.shape)

s_jpg = 0.5
jpg = rescale(jpg, s_jpg)
print(jpg.shape, raw.shape)


s = 0.25
jpg = rescale(jpg, s)
raw = rescale(raw, s)
print(jpg.shape, raw.shape, jpg.dtype, raw.dtype)
# Out:
# (3648, 5472) (1836, 2752)
# (1824, 2736) (1836, 2752)
# (456, 684) (459, 688) float64 float64

# %%
ipyplot.plot_images([jpg, raw],img_width=300,max_images=3)
# Out:
# /home/phd/09/igor/miniconda3/envs/mmdet/lib/python3.7/site-packages/numpy/core/_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
#     <style>
#         #ipyplot-html-viewer-toggle-3hoYQBGJtPxu6EqYNjFQr3 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-3hoYQBGJtPxu6EqYNjFQr3 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-3hoYQBGJtPxu6EqYNjFQr3 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-3hoYQBGJtPxu6EqYNjFQr3:checked ~ #ipyplot-html-viewer-textarea-3hoYQBGJtPxu6EqYNjFQr3 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-3hoYQBGJtPxu6EqYNjFQr3:checked + #ipyplot-html-viewer-label-3hoYQBGJtPxu6EqYNjFQr3:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-3hoYQBGJtPxu6EqYNjFQr3">
#         <label id="ipyplot-html-viewer-label-3hoYQBGJtPxu6EqYNjFQr3" for="ipyplot-html-viewer-toggle-3hoYQBGJtPxu6EqYNjFQr3">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-3hoYQBGJtPxu6EqYNjFQr3" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-79FSFasPg68VFEdCGmC8Zk {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-79FSFasPg68VFEdCGmC8Zk {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-79FSFasPg68VFEdCGmC8Zk">
#     <div class="ipyplot-placeholder-div-79FSFasPg68VFEdCGmC8Zk">
#         <div id="ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk-6dNMA6rBWiHAmXTtii8NDL" class="ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk-6dNMA6rBWiHAmXTtii8NDL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-79FSFasPg68VFEdCGmC8Zk">
#         <div id="ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk-XheKfS6PJPbiQsmLsXwud5" class="ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk-XheKfS6PJPbiQsmLsXwud5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-79FSFasPg68VFEdCGmC8Zk {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-79FSFasPg68VFEdCGmC8Zk {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-79FSFasPg68VFEdCGmC8Zk">
#     <div class="ipyplot-placeholder-div-79FSFasPg68VFEdCGmC8Zk">
#         <div id="ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk-6dNMA6rBWiHAmXTtii8NDL" class="ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk-6dNMA6rBWiHAmXTtii8NDL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-79FSFasPg68VFEdCGmC8Zk">
#         <div id="ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk-XheKfS6PJPbiQsmLsXwud5" class="ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-79FSFasPg68VFEdCGmC8Zk-XheKfS6PJPbiQsmLsXwud5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# ## Matching histograms

# %%
jpg = equalize_hist(jpg)
raw = match_histograms(raw, jpg)

# %%
ipyplot.plot_images([jpg, raw],img_width=300,max_images=3)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-CLKiMYbSRkmzkkBfKgHqn6 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-CLKiMYbSRkmzkkBfKgHqn6 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-CLKiMYbSRkmzkkBfKgHqn6 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-CLKiMYbSRkmzkkBfKgHqn6:checked ~ #ipyplot-html-viewer-textarea-CLKiMYbSRkmzkkBfKgHqn6 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-CLKiMYbSRkmzkkBfKgHqn6:checked + #ipyplot-html-viewer-label-CLKiMYbSRkmzkkBfKgHqn6:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-CLKiMYbSRkmzkkBfKgHqn6">
#         <label id="ipyplot-html-viewer-label-CLKiMYbSRkmzkkBfKgHqn6" for="ipyplot-html-viewer-toggle-CLKiMYbSRkmzkkBfKgHqn6">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-CLKiMYbSRkmzkkBfKgHqn6" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-aZDjPX3aGihTrKca8tNVHJ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-aZDjPX3aGihTrKca8tNVHJ {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-aZDjPX3aGihTrKca8tNVHJ">
#     <div class="ipyplot-placeholder-div-aZDjPX3aGihTrKca8tNVHJ">
#         <div id="ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ-Ui7Ze3Fp4kb6Vuyybz2uYz" class="ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ-Ui7Ze3Fp4kb6Vuyybz2uYz">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-aZDjPX3aGihTrKca8tNVHJ">
#         <div id="ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ-V75pnjUKhZ5uaJB6ok4ND7" class="ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ-V75pnjUKhZ5uaJB6ok4ND7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-aZDjPX3aGihTrKca8tNVHJ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-aZDjPX3aGihTrKca8tNVHJ {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-aZDjPX3aGihTrKca8tNVHJ">
#     <div class="ipyplot-placeholder-div-aZDjPX3aGihTrKca8tNVHJ">
#         <div id="ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ-Ui7Ze3Fp4kb6Vuyybz2uYz" class="ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ-Ui7Ze3Fp4kb6Vuyybz2uYz">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-aZDjPX3aGihTrKca8tNVHJ">
#         <div id="ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ-V75pnjUKhZ5uaJB6ok4ND7" class="ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-aZDjPX3aGihTrKca8tNVHJ-V75pnjUKhZ5uaJB6ok4ND7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %%
ipyplot.plot_images([jpg[-300:-1, -100:-1], raw[-300:-1, -100:-1]],img_width=300,max_images=3)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-RA7uD55ZyqDtMG6Rnks5DU {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-RA7uD55ZyqDtMG6Rnks5DU {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-RA7uD55ZyqDtMG6Rnks5DU {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-RA7uD55ZyqDtMG6Rnks5DU:checked ~ #ipyplot-html-viewer-textarea-RA7uD55ZyqDtMG6Rnks5DU {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-RA7uD55ZyqDtMG6Rnks5DU:checked + #ipyplot-html-viewer-label-RA7uD55ZyqDtMG6Rnks5DU:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-RA7uD55ZyqDtMG6Rnks5DU">
#         <label id="ipyplot-html-viewer-label-RA7uD55ZyqDtMG6Rnks5DU" for="ipyplot-html-viewer-toggle-RA7uD55ZyqDtMG6Rnks5DU">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-RA7uD55ZyqDtMG6Rnks5DU" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-BgzzPxLk9xmQ7KvgCtJBtJ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-BgzzPxLk9xmQ7KvgCtJBtJ {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-BgzzPxLk9xmQ7KvgCtJBtJ">
#     <div class="ipyplot-placeholder-div-BgzzPxLk9xmQ7KvgCtJBtJ">
#         <div id="ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ-JYxq54uahT7hcXRW5SuLAu" class="ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ-JYxq54uahT7hcXRW5SuLAu">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-BgzzPxLk9xmQ7KvgCtJBtJ">
#         <div id="ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ-a9jB7RAUEDAeEeyFrBXNmU" class="ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ-a9jB7RAUEDAeEeyFrBXNmU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-BgzzPxLk9xmQ7KvgCtJBtJ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-BgzzPxLk9xmQ7KvgCtJBtJ {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-BgzzPxLk9xmQ7KvgCtJBtJ">
#     <div class="ipyplot-placeholder-div-BgzzPxLk9xmQ7KvgCtJBtJ">
#         <div id="ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ-JYxq54uahT7hcXRW5SuLAu" class="ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ-JYxq54uahT7hcXRW5SuLAu">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-BgzzPxLk9xmQ7KvgCtJBtJ">
#         <div id="ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ-a9jB7RAUEDAeEeyFrBXNmU" class="ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-BgzzPxLk9xmQ7KvgCtJBtJ-a9jB7RAUEDAeEeyFrBXNmU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# ## Matching

# %%
detector = cv2.xfeatures2d.SIFT_create()
FLANN_INDEX_KDTREE = 1
MIN_MATCH_COUNT  = 10
index_params = dict(algorithm = FLANN_INDEX_KDTREE, trees = 5)
search_params = dict(checks = 50)
flann = cv2.FlannBasedMatcher(index_params, search_params)
img1 = (jpg * 255).astype(np.uint8)
img2 = (raw * 255).astype(np.uint8)
kp1, des1 = detector.detectAndCompute(img1,None)
kp2, des2 = detector.detectAndCompute(img2,None)
matches = flann.knnMatch(des1,des2,k=2)
good = []
for m,n in matches:
    if m.distance < 0.7*n.distance:
        good.append(m)
if len(good)>MIN_MATCH_COUNT:
    src_pts = np.float32([ kp1[m.queryIdx].pt for m in good ]).reshape(-1,1,2)
    dst_pts = np.float32([ kp2[m.trainIdx].pt for m in good ]).reshape(-1,1,2)
    S = cv2.estimateRigidTransform(src_pts, dst_pts, True)
    H, mask = cv2.findHomography(src_pts, dst_pts, cv2.RANSAC,5.0)
    matchesMask = mask.ravel().tolist()
else:
    print("[WARNING] {} ignored, (not enough good matches)")
    H, S, mask = None, None, None
    matchesMask = None

# %%
draw_params = dict(matchColor = (0,255,0), # draw matches in green color
                   singlePointColor = None,
                   matchesMask = matchesMask, # draw only inliers
                   flags = 2)
img3 = cv2.drawMatches(img1,kp1,img2,kp2,good,None,**draw_params)

# %%
ipyplot.plot_images([img3],img_width=600,max_images=3)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-TXRyQTi4w3TmMtzxDArWW8 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-TXRyQTi4w3TmMtzxDArWW8 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-TXRyQTi4w3TmMtzxDArWW8 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-TXRyQTi4w3TmMtzxDArWW8:checked ~ #ipyplot-html-viewer-textarea-TXRyQTi4w3TmMtzxDArWW8 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-TXRyQTi4w3TmMtzxDArWW8:checked + #ipyplot-html-viewer-label-TXRyQTi4w3TmMtzxDArWW8:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-TXRyQTi4w3TmMtzxDArWW8">
#         <label id="ipyplot-html-viewer-label-TXRyQTi4w3TmMtzxDArWW8" for="ipyplot-html-viewer-toggle-TXRyQTi4w3TmMtzxDArWW8">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-TXRyQTi4w3TmMtzxDArWW8" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-YqnUwk3j9kwEqvWbYuTZfq {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-YqnUwk3j9kwEqvWbYuTZfq {
#             width: 600px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-YqnUwk3j9kwEqvWbYuTZfq {
#             width: 600px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-YqnUwk3j9kwEqvWbYuTZfq span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-YqnUwk3j9kwEqvWbYuTZfq span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-YqnUwk3j9kwEqvWbYuTZfq img {
#             width: 600px;
#         }
#
#         div.ipyplot-content-div-YqnUwk3j9kwEqvWbYuTZfq span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-YqnUwk3j9kwEqvWbYuTZfq span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-YqnUwk3j9kwEqvWbYuTZfq]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-YqnUwk3j9kwEqvWbYuTZfq]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-YqnUwk3j9kwEqvWbYuTZfq]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-YqnUwk3j9kwEqvWbYuTZfq">
#     <div class="ipyplot-placeholder-div-YqnUwk3j9kwEqvWbYuTZfq">
#         <div id="ipyplot-content-div-YqnUwk3j9kwEqvWbYuTZfq-Anaxi4LdkzPBy9cMvsdPXf" class="ipyplot-content-div-YqnUwk3j9kwEqvWbYuTZfq">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-YqnUwk3j9kwEqvWbYuTZfq-Anaxi4LdkzPBy9cMvsdPXf">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-YqnUwk3j9kwEqvWbYuTZfq {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-YqnUwk3j9kwEqvWbYuTZfq {
#             width: 600px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-YqnUwk3j9kwEqvWbYuTZfq {
#             width: 600px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-YqnUwk3j9kwEqvWbYuTZfq span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-YqnUwk3j9kwEqvWbYuTZfq span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-YqnUwk3j9kwEqvWbYuTZfq img {
#             width: 600px;
#         }
#
#         div.ipyplot-content-div-YqnUwk3j9kwEqvWbYuTZfq span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-YqnUwk3j9kwEqvWbYuTZfq span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-YqnUwk3j9kwEqvWbYuTZfq]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-YqnUwk3j9kwEqvWbYuTZfq]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-YqnUwk3j9kwEqvWbYuTZfq]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-YqnUwk3j9kwEqvWbYuTZfq">
#     <div class="ipyplot-placeholder-div-YqnUwk3j9kwEqvWbYuTZfq">
#         <div id="ipyplot-content-div-YqnUwk3j9kwEqvWbYuTZfq-Anaxi4LdkzPBy9cMvsdPXf" class="ipyplot-content-div-YqnUwk3j9kwEqvWbYuTZfq">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-YqnUwk3j9kwEqvWbYuTZfq-Anaxi4LdkzPBy9cMvsdPXf">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %%
S
# Out:
# array([[ 9.79774768e-01, -3.47074247e-03,  9.29783728e+00],
#        [-6.78147063e-04,  9.77480811e-01,  6.87113370e+00]])

# %%
H
# Out:
# array([[ 9.83768618e-01, -2.46769119e-03,  8.76185997e+00],
#        [ 3.04681890e-03,  9.76285221e-01,  6.51357388e+00],
#        [ 1.31205787e-05, -7.14089082e-06,  1.00000000e+00]])

# %%
S@np.array([1000, 1000,1])
# Out:
# array([985.6018629 , 983.67379743])

# %%
H@np.array([1000, 1000,1])
# Out:
# array([990.06278647, 985.84561427,   1.00597969])

# %%
y1,y2,x1,x2 = 2000,3000,2000,3000

# %%
X=(s_jpg*np.linalg.inv(H))@np.array([[x1,y1,1],[x2,y2,1]]).T
rx1, ry1 = X.T[0].astype(np.int)
rx2, ry2 = X.T[1].astype(np.int)
print(rx1, rx2, ry1, ry2)
print(X)
jpg = cv2.imread(jpg_fp)
jpg = cv2.cvtColor(jpg, cv2.COLOR_BGR2GRAY)
raw = read_avg_green_raw(raw_fp)

jpg = equalize_hist(jpg)
raw = equalize_hist(raw)
# Out:
# /home/phd/09/igor/miniconda3/envs/mmdet/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_17722/1847414223.py in <module>
#       1 X=(s_jpg*np.linalg.inv(H))@np.array([[x1,y1,1],[x2,y2,1]]).T
# ----> 2 rx1, ry1 = X.T[0].astype(np.int)
#       3 rx2, ry2 = X.T[1].astype(np.int)
#       4 print(rx1, rx2, ry1, ry2)
#       5 print(X)
#
# ValueError: too many values to unpack (expected 2)

# %%
ipyplot.plot_images([jpg[y1:y2, x1:x2], raw[y1//2:y2//2, x1//2:x2//2]],img_width=300,max_images=3)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-RwNFMrCYVa4WpbdcgghLti {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-RwNFMrCYVa4WpbdcgghLti {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-RwNFMrCYVa4WpbdcgghLti {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-RwNFMrCYVa4WpbdcgghLti:checked ~ #ipyplot-html-viewer-textarea-RwNFMrCYVa4WpbdcgghLti {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-RwNFMrCYVa4WpbdcgghLti:checked + #ipyplot-html-viewer-label-RwNFMrCYVa4WpbdcgghLti:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-RwNFMrCYVa4WpbdcgghLti">
#         <label id="ipyplot-html-viewer-label-RwNFMrCYVa4WpbdcgghLti" for="ipyplot-html-viewer-toggle-RwNFMrCYVa4WpbdcgghLti">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-RwNFMrCYVa4WpbdcgghLti" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-JbvywT3W5wrCHSuutWajqv {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-JbvywT3W5wrCHSuutWajqv {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-JbvywT3W5wrCHSuutWajqv {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-JbvywT3W5wrCHSuutWajqv span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-JbvywT3W5wrCHSuutWajqv span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-JbvywT3W5wrCHSuutWajqv img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-JbvywT3W5wrCHSuutWajqv span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-JbvywT3W5wrCHSuutWajqv span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-JbvywT3W5wrCHSuutWajqv]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-JbvywT3W5wrCHSuutWajqv]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-JbvywT3W5wrCHSuutWajqv]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-JbvywT3W5wrCHSuutWajqv">
#     <div class="ipyplot-placeholder-div-JbvywT3W5wrCHSuutWajqv">
#         <div id="ipyplot-content-div-JbvywT3W5wrCHSuutWajqv-Yfw5zLwKEuk722pBaM9qw3" class="ipyplot-content-div-JbvywT3W5wrCHSuutWajqv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-JbvywT3W5wrCHSuutWajqv-Yfw5zLwKEuk722pBaM9qw3">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-JbvywT3W5wrCHSuutWajqv">
#         <div id="ipyplot-content-div-JbvywT3W5wrCHSuutWajqv-AzgnLqB4PiTPsEwhWmAoRi" class="ipyplot-content-div-JbvywT3W5wrCHSuutWajqv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-JbvywT3W5wrCHSuutWajqv-AzgnLqB4PiTPsEwhWmAoRi">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-JbvywT3W5wrCHSuutWajqv {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-JbvywT3W5wrCHSuutWajqv {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-JbvywT3W5wrCHSuutWajqv {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-JbvywT3W5wrCHSuutWajqv span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-JbvywT3W5wrCHSuutWajqv span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-JbvywT3W5wrCHSuutWajqv img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-JbvywT3W5wrCHSuutWajqv span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-JbvywT3W5wrCHSuutWajqv span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-JbvywT3W5wrCHSuutWajqv]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-JbvywT3W5wrCHSuutWajqv]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-JbvywT3W5wrCHSuutWajqv]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-JbvywT3W5wrCHSuutWajqv">
#     <div class="ipyplot-placeholder-div-JbvywT3W5wrCHSuutWajqv">
#         <div id="ipyplot-content-div-JbvywT3W5wrCHSuutWajqv-Yfw5zLwKEuk722pBaM9qw3" class="ipyplot-content-div-JbvywT3W5wrCHSuutWajqv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-JbvywT3W5wrCHSuutWajqv-Yfw5zLwKEuk722pBaM9qw3">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-JbvywT3W5wrCHSuutWajqv">
#         <div id="ipyplot-content-div-JbvywT3W5wrCHSuutWajqv-AzgnLqB4PiTPsEwhWmAoRi" class="ipyplot-content-div-JbvywT3W5wrCHSuutWajqv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-JbvywT3W5wrCHSuutWajqv-AzgnLqB4PiTPsEwhWmAoRi">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %%
ipyplot.plot_images([jpg[y1:y2, x1:x2], raw[ry1:ry2, rx1:rx2]],img_width=300,max_images=3)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-EJjZ3mYLSkR5W7bVpAVxwt {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-EJjZ3mYLSkR5W7bVpAVxwt {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-EJjZ3mYLSkR5W7bVpAVxwt {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-EJjZ3mYLSkR5W7bVpAVxwt:checked ~ #ipyplot-html-viewer-textarea-EJjZ3mYLSkR5W7bVpAVxwt {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-EJjZ3mYLSkR5W7bVpAVxwt:checked + #ipyplot-html-viewer-label-EJjZ3mYLSkR5W7bVpAVxwt:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-EJjZ3mYLSkR5W7bVpAVxwt">
#         <label id="ipyplot-html-viewer-label-EJjZ3mYLSkR5W7bVpAVxwt" for="ipyplot-html-viewer-toggle-EJjZ3mYLSkR5W7bVpAVxwt">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-EJjZ3mYLSkR5W7bVpAVxwt" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-Y3YTU4FKnxNNbGanjmhHTM {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-Y3YTU4FKnxNNbGanjmhHTM {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-Y3YTU4FKnxNNbGanjmhHTM">
#     <div class="ipyplot-placeholder-div-Y3YTU4FKnxNNbGanjmhHTM">
#         <div id="ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM-hpGNX8ekU9ekkgiZGpYBjP" class="ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM-hpGNX8ekU9ekkgiZGpYBjP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Y3YTU4FKnxNNbGanjmhHTM">
#         <div id="ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM-XhcYk3mso9JHQb4ZYnWNjY" class="ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM-XhcYk3mso9JHQb4ZYnWNjY">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-Y3YTU4FKnxNNbGanjmhHTM {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-Y3YTU4FKnxNNbGanjmhHTM {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-Y3YTU4FKnxNNbGanjmhHTM">
#     <div class="ipyplot-placeholder-div-Y3YTU4FKnxNNbGanjmhHTM">
#         <div id="ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM-hpGNX8ekU9ekkgiZGpYBjP" class="ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM-hpGNX8ekU9ekkgiZGpYBjP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Y3YTU4FKnxNNbGanjmhHTM">
#         <div id="ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM-XhcYk3mso9JHQb4ZYnWNjY" class="ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Y3YTU4FKnxNNbGanjmhHTM-XhcYk3mso9JHQb4ZYnWNjY">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %%
X=(s_jpg*H)@np.array([[x1,y1,1],[x2,y2,1]]).T
X
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_17722/1638198895.py in <module>
# ----> 1 X=(s_jpg*H)@np.array([[x1,y1],[x2,y2]]).T
#       2 X
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 2 is different from 3)
